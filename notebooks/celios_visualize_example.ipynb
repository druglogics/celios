# %% [markdown]
# # CELIOS Example Visualization
# ### Exploring toy data outputs
# This notebook demonstrates loading and visualizing CELIOS pipeline outputs.

# %%
# Import necessary modules
import pandas
import os
import sys
import shutil
import pandas
import plotly.graph_objects as go
from celios.core import run_celios

# %%
# Set up paths to access example outputs
NOTEBOOK_DIR = os.getcwd()
ROOT = os.path.dirname(NOTEBOOK_DIR)
RESULTS_DIR = os.path.join(ROOT, 'examples', 'results')

print(f'Results directory: {RESULTS_DIR}')
print(f'Results exist: {os.path.isdir(RESULTS_DIR)}')
# Out:
# Results directory: c:\Users\viviamsb\OneDrive - NTNU\PhD Folder\Pipeline\CELIOS\examples\results
# Results exist: True

# %% [markdown]
# ## Load the master activity matrix from example results

# %%
activity_matrix_path = os.path.join(RESULTS_DIR, 'activity_master_matrix.csv')
activity_matrix = pandas.read_csv(activity_matrix_path, index_col=0)

print(f'Activity matrix shape: {activity_matrix.shape}')
print('First few rows and columns:')
print(activity_matrix.iloc[:5, :5])
# Out:
# Activity matrix shape: (20, 17)
# First few rows and columns:
#                                    symbol  SIDM00826__mutations  \
# AKT1                             ['AKT1']                   NaN
# CCND1                           ['CCND1']                   NaN
# CyclinB_CDK1            ['CCNB1', 'CDK1']                   NaN
# CyclinD_CDK4_6  ['CCND1', 'CDK4', 'CDK6']                   NaN
# ERK_f                  ['MAPK1', 'MAPK3']                   NaN
#
#                 SIDM00136__mutations  SIDM00787__mutations  \
# AKT1                             NaN                   NaN
# CCND1                            NaN                   NaN
# CyclinB_CDK1                     NaN                   NaN
# CyclinD_CDK4_6                   NaN                   NaN
# ERK_f                            NaN                   NaN
#
#                 SIDM00841__mutations
# AKT1                             NaN
# CCND1                            NaN
# CyclinB_CDK1                     NaN
# CyclinD_CDK4_6                   NaN
# ERK_f                            NaN

# %% [markdown]
# ## Check outputs

# %%
# Skip symbol column
activity_matrix = activity_matrix.drop(columns=['symbol'])

# Number of cell lines processed
num_cell_lines = activity_matrix.shape[1]
print(f"Number of cell lines processed: {num_cell_lines}")

# Number of nodes in the activity matrix
num_nodes = activity_matrix.shape[0]
print(f"Number of nodes in the activity matrix: {num_nodes}")
# Out:
# Number of cell lines processed: 16
# Number of nodes in the activity matrix: 20

# %%
# Load master matrix for cell line inspection
master_matrix = pandas.read_csv(os.path.join(ROOT, 'examples', 'results', 'activity_master_matrix.csv'))

# Select cell line in the master matrix
cell_line_to_inspect = 'SIDM00787' # Change this to the desired cell line ID

# Find all data for the selected cell line and organize by data type
cell_line_data = {'symbol': master_matrix['symbol']}

for col in master_matrix.columns:
    if col.startswith(cell_line_to_inspect + '_'):
        data_type = col.split('_', 1)[1]
        cell_line_data[data_type] = master_matrix[col]

# Build new dataframe with symbol and data types
cell_line_df = pandas.DataFrame(cell_line_data)
print(f"Columns in new dataframe: {cell_line_df.columns.tolist()}")
# cell_line_df
# Out:
# Columns in new dataframe: ['symbol', '_mutations', '_cnv', '_TF', '_expression']

# %% [markdown]
# ## Plot Results

# %%
selected_tissue = 'Colon'

# %%
# HEATMAP OF ACTIVITY SCORES
fig = go.Figure(data=go.Heatmap(
    z=activity_matrix.values,
    x=activity_matrix.columns,
    y=activity_matrix.index,
    colorscale='Tropic',
    hoverongaps=True
))

fig.update_layout(
    title=f'Activity Scores Heatmap for {selected_tissue} Cell Lines',
    xaxis_nticks=num_cell_lines,
    yaxis_nticks=num_nodes,
    yaxis_title='Nodes',
    xaxis_title='Cell Lines',
    height=1200,
    width=1200
)
fig.show()

# %%
# HEATMAP OF A SINGLE CELL LINE ACROSS DATA TYPES
fig = go.Figure(data=go.Heatmap(
    z=cell_line_df.drop(columns=['symbol']).values,
    x=cell_line_df.drop(columns=['symbol']).columns,
    y=cell_line_df['symbol'],
    colorscale='Tropic',
    hoverongaps=True
))
fig.update_layout(
    title=f'Activity Scores Heatmap for Cell Line {cell_line_to_inspect}',
    yaxis_nticks=num_nodes,
    yaxis_title='Nodes',
    xaxis_title='Data Types',
    height=1200,
    width=600
)
fig.show()

# %% [markdown]
# ## EXTRA: copy pipeline files

# %%
# COPY MAIN FILES TO CELL LINE FOLDERS 

# def copy_files_to_cell_line_folders(general_files_dir, cell_line_directory):
#     for folder_name in os.listdir(cell_line_directory):
#         folder_path = os.path.join(cell_line_directory, folder_name)
#         if os.path.isdir(folder_path):
#             # Copy files from general_files_dir to the cell line folder
#             for filename in os.listdir(general_files_dir):
#                 src_file = os.path.join(general_files_dir, filename)
#                 dest_file = os.path.join(folder_path, filename)
#                 shutil.copy(src_file, dest_file)

# %%
general_files_dir = os.path.join(ROOT, 'examples', 'results', 'general_files')
cell_line_directory = os.path.join(ROOT, 'examples', 'results', 'colorectal_fullpanel')
# copy_files_to_cell_line_folders(general_files_dir, cell_line_directory)
